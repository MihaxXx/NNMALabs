# %%
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Image
img = 'https://ultralytics.com/images/zidane.jpg'

# Inference
results = model(img)
# Out:
# Using cache found in /Users/mikhail/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2022-9-19 Python-3.9.12 torch-1.12.1 CPU
#
# Fusing layers...
# [W NNPACK.cpp:51] Could not initialize NNPACK! Reason: Unsupported hardware.
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
results.print()
# Out:
# image 1/1: 720x1280 2 persons, 2 ties
# Speed: 1014.0ms pre-process, 1668.4ms inference, 26.5ms NMS per image at shape (1, 3, 384, 640)

# %%
# Image
img = 'panda.jpg'

# Inference
results = model(img)
results.print()
# Out:
# image 1/1: 613x696 1 bear
# Speed: 59.2ms pre-process, 2313.4ms inference, 2.3ms NMS per image at shape (1, 3, 576, 640)

# %%
results.show()

# %%
# !OMP_NUM_THREADS=1 KMP_DUPLICATE_LIB_OK=TRUE python yolov5/export.py --weights yolov5s.pt --img 640 --batch 1  # export at 640x640 with batch size 1
# Out:
# export: data=yolov5/data/coco128.yaml, weights=['yolov5s.pt'], imgsz=[640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript']
# YOLOv5 🚀 2022-9-19 Python-3.9.12 torch-1.12.1 CPU
#
# Fusing layers...
# [W NNPACK.cpp:51] Could not initialize NNPACK! Reason: Unsupported hardware.
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
#
# PyTorch: starting from yolov5s.pt with output shape (1, 25200, 85) (14.1 MB)
#
# TorchScript: starting export with torch 1.12.1...
# TorchScript: export success ✅ 7.5s, saved as yolov5s.torchscript (28.0 MB)
#
# Export complete (9.6s)
# Results saved to /Users/mikhail/Projects/NNMALabs
# Detect:          python detect.py --weights yolov5s.torchscript
# Validate:        python val.py --weights yolov5s.torchscript
# ...

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5s.torchscript')  # local model
# Out:
# Using cache found in /Users/mikhail/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2022-9-19 Python-3.9.12 torch-1.12.1 CPU
#
# Loading yolov5s.torchscript for TorchScript inference...
# Adding AutoShape...

# %%
# Image
img = 'panda.jpg'

# Inference
results = model(img)
results.print()
# Out:
# image 1/1: 613x696 1 bear
# Speed: 28.6ms pre-process, 800.0ms inference, 3.0ms NMS per image at shape (1, 3, 640, 640)

# %%
results.show()
